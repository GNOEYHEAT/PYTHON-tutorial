# %% [markdown]
# # Matplotlib Introduction

# %% [markdown]
# ## pylab 서브패키지

# %%
import matplotlib as mpl
import matplotlib.pylab as plt # pylab

# %%
# %matplotlib inline

# %% [markdown]
# ### 라인 플롯

# %%
plt.title("Plot")
plt.plot([1, 4, 9, 16])
plt.show()

# %%
plt.title("x tick")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.show()

# %% [markdown]
# #### 스타일 지정

# %%
plt.title("'rs--' plot ")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], 'rs--')
plt.show()

# %% [markdown]
# ##### 색깔
# * blue	b
# * green	g
# * red	r
# * cyan	c
# * magenta	m
# * yellow	y
# * black	k
# * white	w

# %% [markdown]
# ######  마커
# * .	point marker
# * ,	pixel marker
# * o	circle marker
# * v	triangle_down marker
# * ^	triangle_up marker
# * <	triangle_left marker
# * \>	triangle_right marker
# * 1	tri_down marker
# * 2	tri_up marker
# * 3	tri_left marker
# * 4	tri_right marker
# * s	square marker
# * p	pentagon marker
# * \*	star marker
# * h	hexagon1 marker
# * H	hexagon2 marker
# * \+	plus marker
# * x	x marker
# * D	diamond marker
# * d	thin_diamond marker

# %% [markdown]
# ###### 선 스타일
# * \-	solid line style
# * --	dashed line style
# * -.	dash-dot line style
# * :	dotted line style

# %% [markdown]
# ###### 기타 스타일
# * olor	c	선 색깔
# * linewidth	lw	선 굵기
# * linestyle	ls	선 스타일
# * marker		마커 종류
# * markersize	ms	마커 크기
# * markeredgecolor	mec	마커 선 색깔
# * markeredgewidth	mew	마커 선 굵기
# * markerfacecolor	mfc	마커 내부 색깔

# %%
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c="b",
         lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.title("stlye example")
plt.show()

# %% [markdown]
# #### 그림 범위 지정

# %%
plt.title("x, y limit")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16],
        c='b', lw=5, ls="--", marker='o', ms=15, mec="g", mew=5, mfc="r")
plt.xlim(0, 50)
plt.ylim(-10, 30)
plt.show()

# %% [markdown]
# ### 틱 설정

# %%
import numpy as np
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title("x, y tick label")
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
plt.yticks([-1, 0, +1])
plt.show()

# %%
C = np.cos(X)
plt.title("LaTeX, string tick label") # $$ 사이에 LaTeX 수학 문자식 삽입
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, 1], ["Low", "Zero", "High"])
plt.show()

# %% [markdown]
# ### 그리드 설정

# %%
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title("Grid add")
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, 1], ["Low", "Zero", "High"])
plt.grid(True)
plt.show()

# %% [markdown]
# ### 여러개의 선을 그리기

# %%
t = np.arange(0., 5., 0.2)
plt.title("multiple line")
plt.plot(t, t, 'r--', t, 0.5 * t**2, 'bs:', t, 0.2 * t**3, 'g^-')
plt.show()

# %% [markdown]
# ### 홀드 명령

# %%
plt.title("Hold") # hold : 복수의 plot 겹쳐그리기
plt.plot([1, 4, 9, 16],
         c="b", lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
# plt.hold(True)   # <- 1,5 버전에서는 이 코드가 필요하다.
plt.plot([9, 16, 4, 1],
         c="k", lw=3, ls=":", marker="s", ms=10, mec="m", mew=5, mfc="c")
# plt.hold(False)  # <- 1,5 버전에서는 이 코드가 필요하다.
plt.show()

# %% [markdown]
# ###  범례
# * best	0
# * upper right	1
# * upper left	2
# * lower left	3
# * lower right	4
# * right	5
# * center left	6
# * center right	7
# * lower center	8
# * upper center	9
# * center	10

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.title("legend plot")
plt.plot(X, C, ls="--", label="cosine")
plt.plot(X, S, ls=":", label="sine")
plt.legend(loc=2)
plt.show()

# %% [markdown]
# ### x축, y축 라벨, 타이틀

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C, label="cosine")
plt.xlabel("time")
plt.ylabel("amplitude")
plt.title("Cosine Plot")
plt.show()

# %% [markdown]
# ## 그림의 구조 : Figure, Axes, Axis

# %% [markdown]
# ### Figure 객체

# %%
np.random.seed(0)
f1 = plt.figure(figsize=(10, 2))
plt.title("figure size : (10, 2)")
plt.plot(np.random.randn(100))
plt.show()

# %%
f1 = plt.figure(1)
plt.title("Figure")
plt.plot([1, 2, 3, 4], 'ro:')

f2 = plt.gcf()
print(f1, id(f1))
print(f2, id(f2))
plt.show()
# Out:
# Figure(432x288) 1525644470368
# Figure(432x288) 1525644470368

# %% [markdown]
# ### Axes 객체와 subplot 명령

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')
print(ax1)

ax2 = plt.subplot(2, 1, 2)
plt.plot(x2, y2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')
print(ax2)

plt.tight_layout()
plt.show()
# Out:
# AxesSubplot(0.125,0.536818;0.775x0.343182)
# AxesSubplot(0.125,0.125;0.775x0.343182)

# %%
np.random.seed(0)

plt.subplot(221)
plt.plot(np.random.rand(5))
plt.title("axes 1")

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title("axes 2")

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title("axes 3")

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title("axes 4")

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2)

np.random.seed(0)
axes[0, 0].plot(np.random.rand(5))
axes[0, 0].set_title("axes 1")
axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title("axes 2")
axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title("axes 3")
axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title("axes 4")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Axis 객체와 축

# %%
fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("2y figure")
ax0.plot([10, 5, 2, 9, 7], 'r-', label="y0")
ax0.set_ylabel("y0")
ax0.grid(False)
ax1.plot([100, 200, 220, 180, 120], 'g:', label="y1")
ax1.set_ylabel("y1")
ax1.grid(False)
ax0.set_xlabel("share x")
plt.show()

# %% [markdown]
# ## 한글 사용
